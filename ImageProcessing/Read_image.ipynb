# %%
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
import matplotlib.pylab as plt

# %% [markdown]
# ##Read Image

# %%
myImg = cv.imread('dog.jpeg')
cv2_imshow(myImg)
# Out:
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7F9DFF6AB070>

# %% [markdown]
# ##Step3: Image Contours and Histograms

# %%
# Check the image matrix data type (could know the bit depth of the image)
print(myImg.dtype)
# Check the height of image 0-->row, 1-->column, 2-->channel
print(myImg.shape[0])
# Check the width of image 
print(myImg.shape[1])
# Check the number of channels of the image
print(myImg.shape[2])
# Out:
# uint8
# 194
# 259
# 3

# %% [markdown]
# ### Generate Histogram of color image and grayscale image

# %% [markdown]
# Display the histogram of all the pixels in the color image

# %% [markdown]
# Display the histogram of R, G, B channel.

# %%
color = ('b','g','r')
for i,col in enumerate(color):
    histr = cv.calcHist([myImg],[i],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
plt.show()

# %%
gray_image = cv.cvtColor(myImg, cv.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=259x194 at 0x7F9DFF5F27C0>

# %%
plt.hist(gray_image.ravel(),bins = 256, range = [0, 256])
plt.show()

# %%
print(myImg)
# Out:
# [[[ 55  79  47]
#   [ 55  79  47]
#   [ 54  78  46]
#   ...
#   [ 17  24   3]
#   [ 15  24   3]
#   [ 15  24   3]]
#
#  [[ 55  79  47]
#   [ 54  78  46]
#   [ 54  78  46]
#   ...
#   [ 17  24   3]
#   [ 15  24   3]
#   [ 15  24   3]]
#
#  [[ 54  78  46]
#   [ 54  78  46]
#   [ 53  77  45]
#   ...
#   [ 16  23   2]
#   [ 16  23   2]
#   [ 16  23   2]]
#
#  ...
#
#  [[ 44 140  99]
#   [ 44 140  99]
#   [ 45 141 100]
#   ...
#   [ 44 144 102]
#   [ 44 145 100]
#   [ 44 145 100]]
#
#  [[ 39 141  99]
#   [ 39 141  99]
#   [ 40 142 100]
#   ...
#   [ 43 145 103]
#   [ 41 146 103]
#   [ 41 146 103]]
#
#  [[ 35 142  99]
#   [ 35 142  99]
#   [ 36 143 100]
#   ...
#   [ 41 146 103]
#   [ 39 146 103]
#   [ 39 146 103]]]

# %%
print(myImg[10, 25])
# Out:
# array([26, 46, 23], dtype=uint8)
